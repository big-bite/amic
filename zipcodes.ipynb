# %%
import numpy as np
import pandas as pd

# %%
file = "playground/ibamco_sheet.xlsx"
sheet = "main"

# %%
df = pd.read_excel(file, sheet)

# %%
df
# Out:
#         ID               Origin           media               url  \
# 0        0   Iberfier, CAC, OJD        el 9 nou        el9nou.cat
# 1        2   Iberfier, CAC, OJD          betevé        beteve.cat
# 2        3   Iberfier, CAC, OJD     pirineus tv    pirineustv.cat
# 3        4   Iberfier, CAC, OJD  ràdio sabadell  radiosabadell.fm
# 4        5  AMIC, Iberfier, OJD     adolescents   adolescents.cat
# ...    ...                  ...             ...               ...
# 1370  3691                  OJD        urgelltv      urgelltv.cat
# 1371  3692                  OJD         21radio       21radio.cat
# 1372  3693                  OJD             aue           aue.cat
# 1373  3694                  OJD         fembase       fembase.cat
# 1374  3695                  OJD          amicib      amicib.media
#
#      zipcode_iber zipcode_cac
# 0           08500       08500
# 1           08018       08099
# 2           25700       25700
# 3           08202       08202
# ...
